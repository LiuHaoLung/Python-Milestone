# %% [markdown]
# # Business Case for AudioBooks without Early Stopping

# %% [markdown]
# The input layer consisting of 10 units, this is from the csv, there are only two output nodes as there are only two possibilities 0 and 1, the net with two hidden layers and the number of units in each hidden layer will be 50.
#
# For a prototype of an algorithm 50 is a good value, 50 hidden units in the hidden layers provide enough complexity, so expect the algorithm to be much more sophisticated than a linear or logistic regression, at the same time we don't want to put too many units, initially as we want to complete the learning as fast as possible and see if anything is being learned at all.

# %% [markdown]
# ### Create the machine learning algorithm

# %% [markdown]
# #### 1. Import the relevant libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# #### 2. Load the data

# %%
# this npz will story each of the three datasets as we load them

npz = np.load('Audiobooks_data_train.npz')

# extract the inputs
# make sure the model learns correctly, expect all inputs to be floats
# the astype method can creates a copy of the array, cast to a specific type

train_inputs = npz['inputs'].astype(np.float)

# extract the targets
# the targets are 0 and 1, but we are not completely certain if they'll be extracted as integers, floats or booleans
# it can use the same method astype and make sure their data type will be np.int

train_targets = npz['targets'].astype(np.int)


npz = np.load('Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)


npz = np.load('Audiobooks_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %% [markdown]
# #### 3. Model

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                            tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                            tf.keras.layers.Dense(output_size, activation = 'softmax')
                            ])

# use this loss to ensure the integer targets are one-hot encoded appropriately when calculating the loss

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])


# have not set the two hyperparameters the batch size and the epochs
# speaking of the batch size, we already said that in this example we won't take advantage of iterable objects that contain the data,
# instead will employ simple arrays while the batching itself will be indicated when we fit the model in a minute or two
# if you were dealing with arrays as we are now, indicating the batch size here would automatically batch the data during the training process



batch_size = 100
max_epochs = 100

model.fit(train_inputs, 
          train_targets,
          batch_size = batch_size,
          epochs = max_epochs,
          validation_data = (validation_inputs, validation_targets),
          verbose = 2
         )


# through the training process
# it can know the training loss is consistently decreasing
# but the validation loss was sometimes increasing
# so it is pretty obviously the model is overfitting
# so in this time, setting an early stopping mechanism really does make a different
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 1s - loss: 0.6520 - accuracy: 0.6387 - val_loss: 0.5256 - val_accuracy: 0.7494
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.4833 - accuracy: 0.7650 - val_loss: 0.4450 - val_accuracy: 0.7808
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.4247 - accuracy: 0.7818 - val_loss: 0.4001 - val_accuracy: 0.7987
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.3940 - accuracy: 0.7935 - val_loss: 0.3720 - val_accuracy: 0.8188
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.3768 - accuracy: 0.8005 - val_loss: 0.3615 - val_accuracy: 0.8166
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.3656 - accuracy: 0.8005 - val_loss: 0.3471 - val_accuracy: 0.8166
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.3570 - accuracy: 0.8092 - val_loss: 0.3405 - val_accuracy: 0.8345
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.3510 - accuracy: 0.8181 - val_loss: 0.3534 - val_accuracy: 0.8031
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.3499 - accuracy: 0.8122 - val_loss: 0.3330 - val_accuracy: 0.8210
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.3434 - accuracy: 0.8156 - val_loss: 0.3369 - val_accuracy: 0.8166
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.3441 - accuracy: 0.8080 - val_loss: 0.3282 - val_accuracy: 0.8188
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.3354 - accuracy: 0.8170 - val_loss: 0.3301 - val_accuracy: 0.8255
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.3348 - accuracy: 0.8212 - val_loss: 0.3293 - val_accuracy: 0.8345
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.3347 - accuracy: 0.8178 - val_loss: 0.3344 - val_accuracy: 0.8054
# Epoch 15/100
# 3579/3579 - 0s - loss: 0.3318 - accuracy: 0.8184 - val_loss: 0.3333 - val_accuracy: 0.8121
# Epoch 16/100
# 3579/3579 - 0s - loss: 0.3339 - accuracy: 0.8139 - val_loss: 0.3270 - val_accuracy: 0.8188
# Epoch 17/100
# 3579/3579 - 0s - loss: 0.3295 - accuracy: 0.8215 - val_loss: 0.3224 - val_accuracy: 0.8210
# Epoch 18/100
# 3579/3579 - 0s - loss: 0.3281 - accuracy: 0.8206 - val_loss: 0.3295 - val_accuracy: 0.8188
# Epoch 19/100
# 3579/3579 - 0s - loss: 0.3264 - accuracy: 0.8245 - val_loss: 0.3284 - val_accuracy: 0.8233
# Epoch 20/100
# 3579/3579 - 0s - loss: 0.3271 - accuracy: 0.8220 - val_loss: 0.3198 - val_accuracy: 0.8255
# Epoch 21/100
# 3579/3579 - 0s - loss: 0.3278 - accuracy: 0.8226 - val_loss: 0.3184 - val_accuracy: 0.8367
# Epoch 22/100
# 3579/3579 - 0s - loss: 0.3243 - accuracy: 0.8262 - val_loss: 0.3240 - val_accuracy: 0.8098
# Epoch 23/100
# 3579/3579 - 0s - loss: 0.3231 - accuracy: 0.8265 - val_loss: 0.3251 - val_accuracy: 0.8143
# Epoch 24/100
# 3579/3579 - 0s - loss: 0.3241 - accuracy: 0.8215 - val_loss: 0.3165 - val_accuracy: 0.8277
# Epoch 25/100
# 3579/3579 - 0s - loss: 0.3216 - accuracy: 0.8251 - val_loss: 0.3165 - val_accuracy: 0.8367
# Epoch 26/100
# 3579/3579 - 0s - loss: 0.3211 - accuracy: 0.8259 - val_loss: 0.3167 - val_accuracy: 0.8322
# Epoch 27/100
# 3579/3579 - 0s - loss: 0.3180 - accuracy: 0.8284 - val_loss: 0.3128 - val_accuracy: 0.8345
# Epoch 28/100
# 3579/3579 - 0s - loss: 0.3260 - accuracy: 0.8240 - val_loss: 0.3204 - val_accuracy: 0.8255
# Epoch 29/100
# 3579/3579 - 0s - loss: 0.3184 - accuracy: 0.8251 - val_loss: 0.3268 - val_accuracy: 0.8188
# Epoch 30/100
# 3579/3579 - 0s - loss: 0.3166 - accuracy: 0.8243 - val_loss: 0.3117 - val_accuracy: 0.8412
# Epoch 31/100
# 3579/3579 - 0s - loss: 0.3172 - accuracy: 0.8304 - val_loss: 0.3426 - val_accuracy: 0.8121
# Epoch 32/100
# 3579/3579 - 0s - loss: 0.3197 - accuracy: 0.8287 - val_loss: 0.3195 - val_accuracy: 0.8277
# Epoch 33/100
# 3579/3579 - 0s - loss: 0.3170 - accuracy: 0.8265 - val_loss: 0.3198 - val_accuracy: 0.8233
# Epoch 34/100
# 3579/3579 - 0s - loss: 0.3148 - accuracy: 0.8237 - val_loss: 0.3315 - val_accuracy: 0.8233
# Epoch 35/100
# 3579/3579 - 0s - loss: 0.3187 - accuracy: 0.8259 - val_loss: 0.3186 - val_accuracy: 0.8367
# Epoch 36/100
# 3579/3579 - 0s - loss: 0.3177 - accuracy: 0.8209 - val_loss: 0.3146 - val_accuracy: 0.8345
# Epoch 37/100
# 3579/3579 - 0s - loss: 0.3160 - accuracy: 0.8217 - val_loss: 0.3345 - val_accuracy: 0.7852
# Epoch 38/100
# 3579/3579 - 0s - loss: 0.3155 - accuracy: 0.8273 - val_loss: 0.3136 - val_accuracy: 0.8277
# Epoch 39/100
# 3579/3579 - 0s - loss: 0.3126 - accuracy: 0.8273 - val_loss: 0.3233 - val_accuracy: 0.8166
# Epoch 40/100
# 3579/3579 - 0s - loss: 0.3147 - accuracy: 0.8240 - val_loss: 0.3195 - val_accuracy: 0.8345
# Epoch 41/100
# 3579/3579 - 0s - loss: 0.3141 - accuracy: 0.8349 - val_loss: 0.3244 - val_accuracy: 0.8255
# Epoch 42/100
# 3579/3579 - 0s - loss: 0.3149 - accuracy: 0.8254 - val_loss: 0.3214 - val_accuracy: 0.8277
# Epoch 43/100
# 3579/3579 - 0s - loss: 0.3132 - accuracy: 0.8321 - val_loss: 0.3133 - val_accuracy: 0.8322
# Epoch 44/100
# 3579/3579 - 0s - loss: 0.3128 - accuracy: 0.8231 - val_loss: 0.3247 - val_accuracy: 0.8277
# Epoch 45/100
# 3579/3579 - 0s - loss: 0.3156 - accuracy: 0.8290 - val_loss: 0.3200 - val_accuracy: 0.8054
# Epoch 46/100
# 3579/3579 - 0s - loss: 0.3174 - accuracy: 0.8259 - val_loss: 0.3220 - val_accuracy: 0.8233
# Epoch 47/100
# 3579/3579 - 0s - loss: 0.3138 - accuracy: 0.8262 - val_loss: 0.3213 - val_accuracy: 0.8255
# Epoch 48/100
# 3579/3579 - 0s - loss: 0.3151 - accuracy: 0.8256 - val_loss: 0.3173 - val_accuracy: 0.8277
# Epoch 49/100
# 3579/3579 - 0s - loss: 0.3131 - accuracy: 0.8351 - val_loss: 0.3154 - val_accuracy: 0.8345
# Epoch 50/100
# 3579/3579 - 0s - loss: 0.3111 - accuracy: 0.8259 - val_loss: 0.3171 - val_accuracy: 0.8188
# Epoch 51/100
# 3579/3579 - 0s - loss: 0.3106 - accuracy: 0.8273 - val_loss: 0.3181 - val_accuracy: 0.8412
# Epoch 52/100
# 3579/3579 - 0s - loss: 0.3096 - accuracy: 0.8268 - val_loss: 0.3211 - val_accuracy: 0.8233
# Epoch 53/100
# 3579/3579 - 0s - loss: 0.3104 - accuracy: 0.8251 - val_loss: 0.3154 - val_accuracy: 0.8389
# Epoch 54/100
# 3579/3579 - 0s - loss: 0.3098 - accuracy: 0.8296 - val_loss: 0.3196 - val_accuracy: 0.8277
# Epoch 55/100
# 3579/3579 - 0s - loss: 0.3098 - accuracy: 0.8270 - val_loss: 0.3119 - val_accuracy: 0.8345
# Epoch 56/100
# 3579/3579 - 0s - loss: 0.3145 - accuracy: 0.8282 - val_loss: 0.3260 - val_accuracy: 0.8166
# Epoch 57/100
# 3579/3579 - 0s - loss: 0.3144 - accuracy: 0.8251 - val_loss: 0.3155 - val_accuracy: 0.8322
# Epoch 58/100
# 3579/3579 - 0s - loss: 0.3122 - accuracy: 0.8259 - val_loss: 0.3365 - val_accuracy: 0.8277
# Epoch 59/100
# 3579/3579 - 0s - loss: 0.3129 - accuracy: 0.8234 - val_loss: 0.3174 - val_accuracy: 0.8300
# Epoch 60/100
# 3579/3579 - 0s - loss: 0.3092 - accuracy: 0.8326 - val_loss: 0.3247 - val_accuracy: 0.8255
# Epoch 61/100
# 3579/3579 - 0s - loss: 0.3110 - accuracy: 0.8312 - val_loss: 0.3090 - val_accuracy: 0.8345
# Epoch 62/100
# 3579/3579 - 0s - loss: 0.3088 - accuracy: 0.8301 - val_loss: 0.3229 - val_accuracy: 0.8345
# Epoch 63/100
# 3579/3579 - 0s - loss: 0.3110 - accuracy: 0.8301 - val_loss: 0.3138 - val_accuracy: 0.8255
# Epoch 64/100
# 3579/3579 - 0s - loss: 0.3082 - accuracy: 0.8332 - val_loss: 0.3196 - val_accuracy: 0.8345
# Epoch 65/100
# 3579/3579 - 0s - loss: 0.3082 - accuracy: 0.8310 - val_loss: 0.3132 - val_accuracy: 0.8210
# Epoch 66/100
# 3579/3579 - 0s - loss: 0.3107 - accuracy: 0.8245 - val_loss: 0.3191 - val_accuracy: 0.8255
# Epoch 67/100
# 3579/3579 - 0s - loss: 0.3067 - accuracy: 0.8326 - val_loss: 0.3264 - val_accuracy: 0.8210
# Epoch 68/100
# 3579/3579 - 0s - loss: 0.3087 - accuracy: 0.8217 - val_loss: 0.3190 - val_accuracy: 0.8233
# Epoch 69/100
# 3579/3579 - 0s - loss: 0.3071 - accuracy: 0.8346 - val_loss: 0.3169 - val_accuracy: 0.8322
# Epoch 70/100
# 3579/3579 - 0s - loss: 0.3066 - accuracy: 0.8335 - val_loss: 0.3210 - val_accuracy: 0.8277
# Epoch 71/100
# 3579/3579 - 0s - loss: 0.3072 - accuracy: 0.8357 - val_loss: 0.3330 - val_accuracy: 0.8188
# Epoch 72/100
# 3579/3579 - 0s - loss: 0.3041 - accuracy: 0.8296 - val_loss: 0.3163 - val_accuracy: 0.8345
# Epoch 73/100
# 3579/3579 - 0s - loss: 0.3082 - accuracy: 0.8270 - val_loss: 0.3208 - val_accuracy: 0.8345
# Epoch 74/100
# 3579/3579 - 0s - loss: 0.3059 - accuracy: 0.8338 - val_loss: 0.3121 - val_accuracy: 0.8389
# Epoch 75/100
# 3579/3579 - 0s - loss: 0.3114 - accuracy: 0.8248 - val_loss: 0.3159 - val_accuracy: 0.8166
# Epoch 76/100
# 3579/3579 - 0s - loss: 0.3102 - accuracy: 0.8254 - val_loss: 0.3204 - val_accuracy: 0.8255
# Epoch 77/100
# 3579/3579 - 0s - loss: 0.3070 - accuracy: 0.8296 - val_loss: 0.3212 - val_accuracy: 0.8322
# Epoch 78/100
# 3579/3579 - 0s - loss: 0.3120 - accuracy: 0.8265 - val_loss: 0.3266 - val_accuracy: 0.8143
# Epoch 79/100
# 3579/3579 - 0s - loss: 0.3083 - accuracy: 0.8335 - val_loss: 0.3302 - val_accuracy: 0.8300
# Epoch 80/100
# 3579/3579 - 0s - loss: 0.3094 - accuracy: 0.8284 - val_loss: 0.3214 - val_accuracy: 0.8300
# Epoch 81/100
# 3579/3579 - 0s - loss: 0.3047 - accuracy: 0.8346 - val_loss: 0.3193 - val_accuracy: 0.8322
# Epoch 82/100
# 3579/3579 - 0s - loss: 0.3088 - accuracy: 0.8256 - val_loss: 0.3175 - val_accuracy: 0.8233
# Epoch 83/100
# 3579/3579 - 0s - loss: 0.3054 - accuracy: 0.8329 - val_loss: 0.3164 - val_accuracy: 0.8277
# Epoch 84/100
# 3579/3579 - 0s - loss: 0.3071 - accuracy: 0.8293 - val_loss: 0.3212 - val_accuracy: 0.8233
# Epoch 85/100
# 3579/3579 - 0s - loss: 0.3046 - accuracy: 0.8346 - val_loss: 0.3134 - val_accuracy: 0.8389
# Epoch 86/100
# 3579/3579 - 0s - loss: 0.3036 - accuracy: 0.8338 - val_loss: 0.3157 - val_accuracy: 0.8277
# Epoch 87/100
# 3579/3579 - 0s - loss: 0.3078 - accuracy: 0.8265 - val_loss: 0.3191 - val_accuracy: 0.8300
# Epoch 88/100
# 3579/3579 - 0s - loss: 0.3095 - accuracy: 0.8268 - val_loss: 0.3377 - val_accuracy: 0.8143
# Epoch 89/100
# 3579/3579 - 0s - loss: 0.3112 - accuracy: 0.8279 - val_loss: 0.3253 - val_accuracy: 0.8255
# Epoch 90/100
# 3579/3579 - 0s - loss: 0.3036 - accuracy: 0.8405 - val_loss: 0.3137 - val_accuracy: 0.8277
# Epoch 91/100
# 3579/3579 - 0s - loss: 0.3027 - accuracy: 0.8354 - val_loss: 0.3122 - val_accuracy: 0.8367
# Epoch 92/100
# 3579/3579 - 0s - loss: 0.3043 - accuracy: 0.8304 - val_loss: 0.3259 - val_accuracy: 0.8054
# Epoch 93/100
# 3579/3579 - 0s - loss: 0.3076 - accuracy: 0.8251 - val_loss: 0.3240 - val_accuracy: 0.8210
# Epoch 94/100
# 3579/3579 - 0s - loss: 0.3080 - accuracy: 0.8262 - val_loss: 0.3297 - val_accuracy: 0.8277
# Epoch 95/100
# 3579/3579 - 0s - loss: 0.3066 - accuracy: 0.8293 - val_loss: 0.3104 - val_accuracy: 0.8322
# Epoch 96/100
# 3579/3579 - 0s - loss: 0.3053 - accuracy: 0.8324 - val_loss: 0.3287 - val_accuracy: 0.8255
# Epoch 97/100
# 3579/3579 - 0s - loss: 0.3057 - accuracy: 0.8315 - val_loss: 0.3247 - val_accuracy: 0.8277
# Epoch 98/100
# 3579/3579 - 0s - loss: 0.3066 - accuracy: 0.8234 - val_loss: 0.3168 - val_accuracy: 0.8322
# Epoch 99/100
# 3579/3579 - 0s - loss: 0.3070 - accuracy: 0.8307 - val_loss: 0.3299 - val_accuracy: 0.8367
# Epoch 100/100
# 3579/3579 - 0s - loss: 0.3066 - accuracy: 0.8256 - val_loss: 0.3277 - val_accuracy: 0.8255
